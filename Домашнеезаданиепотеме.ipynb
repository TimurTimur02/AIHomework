# %%
from google.colab import files
import pandas as pd
import numpy as np

# %%
uploaded = files.upload()

filename = list(uploaded.keys())[0]

df = pd.read_csv(filename)
# Out:
#      <input type="file" id="files-610c5a29-6947-4912-8e60-3b4ac5a58dc6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-610c5a29-6947-4912-8e60-3b4ac5a58dc6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
count_nans = df.isnull().sum()
print(count_nans)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.fillna(method = 'bfill')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
for column in df.columns:
    unique_values = df[column].value_counts()
    print(f"Уникальные значения в столбце '{column}':\n{unique_values}\n")
# Out:
# Уникальные значения в столбце 'PassengerId':
# 1      1
# 599    1
# 588    1
# 589    1
# 590    1
#       ..
# 301    1
# 302    1
# 303    1
# 304    1
# 891    1
# Name: PassengerId, Length: 891, dtype: int64
#
# Уникальные значения в столбце 'Survived':
# 0    549
# 1    342
# Name: Survived, dtype: int64
#
# Уникальные значения в столбце 'Pclass':
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64
#
# Уникальные значения в столбце 'Name':
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# ...

# %%
min_values = df.min()

max_values = df.max()

print("Минимальные значения:")
print(min_values)

print("\nМаксимальные значения:")
print(max_values)
# Out:
# Минимальные значения:
# PassengerId                      1
# Survived                         0
# Pclass                           1
# Name           Abbing, Mr. Anthony
# Sex                         female
# Age                           0.42
# SibSp                            0
# Parch                            0
# Ticket                      110152
# Fare                           0.0
# dtype: object
#
# Максимальные значения:
# PassengerId                            891
# Survived                                 1
# Pclass                                   3
# Name           van Melkebeke, Mr. Philemon
# Sex                                   male
# Age                                   80.0
# SibSp                                    8
# Parch                                    6
# Ticket                           WE/P 5735
# Fare                              512.3292
# dtype: object
# ...

# %%
correlation_matrix = df.corr()

print(correlation_matrix)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000
# ...

# %% [markdown]
# Из корреляционной таблицы можно сделать вывод: На "Survived" отрицательно повлияли: SibSP, Pclass,PassengerId, Age.

# %%
print('Домашнее задание 6')
# Out:
# Домашнее задание 6

# %%
from google.colab import files

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt

filename = 'Titanic-Dataset.csv'

df = pd.read_csv(filename)

target_column = 'Survived'

correlation = df.corr()[target_column]

plt.figure(figsize=(6, 6))
sns.heatmap(pd.DataFrame(correlation), cmap='plasma', annot=True, fmt=".2f", linewidths=0.5)
plt.title(f'Влияние столбцов на "{target_column}"')
plt.show()
# Out:
# <ipython-input-33-83bf0fbeca53>:15: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()[target_column]
